# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = '{:.6f}'.format  

# 그래프에서 한글 깨짐 방지
import platform
if platform.system() == "Darwin":          # MAC인 경우
    plt.rc('font', family ="AppleGothic")
else:
    plt.rc('font',family='Malgun Gothic')

#멧플로립에서 음수를 표시
plt.rc('axes',unicode_minus=False)

#워닝 메시지
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('./datasets/원본data.csv',index_col=0)
df1['종가']=df1['종가'].pct_change()
df1=df1.dropna(axis=0)
df1
# Out:
#             재고순환지표     경제심리지수     기계류내수출        건설수주액    수출입물가비율         코스피
# Date
# 2008-02   3.900000 112.000000  98.400000  9246.100000 103.700000 1775.300000  \
# 2008-03   3.200000 110.500000  98.400000  9434.400000 102.200000 1691.000000
# 2008-04   0.400000 109.400000  98.900000 10121.700000 100.700000 1705.800000
# 2008-05  -1.600000 106.100000  98.500000  9955.600000  98.600000 1758.200000
# 2008-06  -5.700000 103.400000  97.200000  8975.200000  96.700000 1793.900000
# ...            ...        ...        ...          ...        ...         ...
# 2022-12 -10.400000  92.700000 115.400000 10568.500000  85.200000 2336.400000
# 2023-01 -15.400000  90.900000 111.200000 13969.700000  85.100000 2380.400000
# 2023-02 -16.200000  91.100000 106.900000 14725.600000  84.600000 2391.300000
# 2023-03 -16.500000  91.100000 101.000000 14189.900000  84.400000 2410.100000
# 2023-04 -16.900000  92.300000 101.500000 10336.900000  84.300000 2463.700000
#
#               장단기            외환보유액     뉴스심리지수         원달러  ...       CD
# Date                                                       ...
# 2008-02  0.530000 262364808.000000  97.880000  944.100000  ... 5.460000  \
# 2008-03  0.310000 264245660.000000  88.120000  946.700000  ... 5.170000
# 2008-04  0.140000 260482546.000000 103.730000  983.500000  ... 5.390000
# 2008-05  0.220000 258198958.000000  93.060000 1009.100000  ... 5.360000
# 2008-06  0.420000 258097988.000000  76.310000 1033.600000  ... 5.360000
# ...           ...              ...        ...         ...  ...      ...
# 2022-12  0.840000 423163664.000000  83.390000 1304.210000  ... 4.030000
# 2023-01  0.450000 429967671.000000  93.790000 1269.020000  ... 3.980000
# 2023-02  0.180000 425286150.000000  97.480000 1221.780000  ... 3.590000
# 2023-03  0.070000 426069328.000000  94.170000 1310.950000  ... 3.610000
# 2023-04 -0.050000 426683640.000000  95.030000 1307.890000  ... 3.590000
#
#                유가        G20      미장단기          거래량       구리      천연가스
# Date
# 2008-02 26.276930 101.286800  1.530000 13564.000000 3.273000  7.740000  \
# 2008-03 26.771666 100.974300  1.930000  9948.000000 3.928500  9.346000
# 2008-04 27.311699 100.601400  1.770000 13964.000000 3.806500  9.724000
# 2008-05 25.481760 100.145200  1.410000 16690.000000 3.694500 10.561000
# 2008-06 25.621851  99.593290  1.470000 14445.000000 3.596500 11.969000
# ...           ...        ...       ...          ...      ...       ...
# 2022-12 76.773430  98.935240 -0.720000  8411.000000 3.817500  6.738000
# 2023-01 78.254589  98.971380 -0.610000 10487.000000 3.795250  4.273500
# 2023-02 74.513809  99.024580 -0.700000  9732.000000 4.111000  2.468000
# 2023-03 73.301552  99.081200 -0.880000 14870.000000 4.076000  2.765000
# 2023-04 74.881462  99.135100 -0.540000  9171.000000 4.045500  2.097000
#
#                 은           금        종가
# Date
# 2008-02 16.916000  913.500000 -0.102030
# 2008-03 20.180000  984.200000 -0.026894
# 2008-04 16.935000  887.800000  0.105239
# 2008-05 16.205000  850.900000  0.094183
# 2008-06 16.958000  897.000000 -0.023686
# ...           ...         ...       ...
# 2022-12 22.841000 1815.200000  0.030911
# 2023-01 24.328000 1835.800000 -0.063960
# 2023-02 23.609000 1927.800000  0.071121
# 2023-03 20.766000 1840.500000  0.034130
# 2023-04 24.021000 1983.900000 -0.000645
#
# [183 rows x 22 columns]

# %%
df=pd.read_csv('./datasets/원본data.csv',index_col=0)
df
# Out:
#             재고순환지표     경제심리지수     기계류내수출        건설수주액    수출입물가비율         코스피
# Date
# 2008-01   5.000000 112.100000  98.500000 10384.800000 105.100000 1853.700000  \
# 2008-02   3.900000 112.000000  98.400000  9246.100000 103.700000 1775.300000
# 2008-03   3.200000 110.500000  98.400000  9434.400000 102.200000 1691.000000
# 2008-04   0.400000 109.400000  98.900000 10121.700000 100.700000 1705.800000
# 2008-05  -1.600000 106.100000  98.500000  9955.600000  98.600000 1758.200000
# ...            ...        ...        ...          ...        ...         ...
# 2022-12 -10.400000  92.700000 115.400000 10568.500000  85.200000 2336.400000
# 2023-01 -15.400000  90.900000 111.200000 13969.700000  85.100000 2380.400000
# 2023-02 -16.200000  91.100000 106.900000 14725.600000  84.600000 2391.300000
# 2023-03 -16.500000  91.100000 101.000000 14189.900000  84.400000 2410.100000
# 2023-04 -16.900000  92.300000 101.500000 10336.900000  84.300000 2463.700000
#
#               장단기            외환보유액     뉴스심리지수         원달러  ...       CD
# Date                                                       ...
# 2008-01  0.670000 261870733.000000  98.540000  936.800000  ... 5.840000  \
# 2008-02  0.530000 262364808.000000  97.880000  944.100000  ... 5.460000
# 2008-03  0.310000 264245660.000000  88.120000  946.700000  ... 5.170000
# 2008-04  0.140000 260482546.000000 103.730000  983.500000  ... 5.390000
# 2008-05  0.220000 258198958.000000  93.060000 1009.100000  ... 5.360000
# ...           ...              ...        ...         ...  ...      ...
# 2022-12  0.840000 423163664.000000  83.390000 1304.210000  ... 4.030000
# 2023-01  0.450000 429967671.000000  93.790000 1269.020000  ... 3.980000
# 2023-02  0.180000 425286150.000000  97.480000 1221.780000  ... 3.590000
# 2023-03  0.070000 426069328.000000  94.170000 1310.950000  ... 3.610000
# 2023-04 -0.050000 426683640.000000  95.030000 1307.890000  ... 3.590000
#
#                유가        G20      미장단기          거래량       구리      천연가스
# Date
# 2008-01 26.816444 101.558900  1.030000 11548.000000 3.064000  7.850000  \
# 2008-02 26.276930 101.286800  1.530000 13564.000000 3.273000  7.740000
# 2008-03 26.771666 100.974300  1.930000  9948.000000 3.928500  9.346000
# 2008-04 27.311699 100.601400  1.770000 13964.000000 3.806500  9.724000
# 2008-05 25.481760 100.145200  1.410000 16690.000000 3.694500 10.561000
# ...           ...        ...       ...          ...      ...       ...
# 2022-12 76.773430  98.935240 -0.720000  8411.000000 3.817500  6.738000
# 2023-01 78.254589  98.971380 -0.610000 10487.000000 3.795250  4.273500
# 2023-02 74.513809  99.024580 -0.700000  9732.000000 4.111000  2.468000
# 2023-03 73.301552  99.081200 -0.880000 14870.000000 4.076000  2.765000
# 2023-04 74.881462  99.135100 -0.540000  9171.000000 4.045500  2.097000
#
#                 은           금          종가
# Date
# 2008-01 15.290000  860.000000 1000.000000
# 2008-02 16.916000  913.500000  897.970000
# 2008-03 20.180000  984.200000  873.820000
# 2008-04 16.935000  887.800000  965.780000
# 2008-05 16.205000  850.900000 1056.740000
# ...           ...         ...         ...
# 2022-12 22.841000 1815.200000 1435.740000
# 2023-01 24.328000 1835.800000 1343.910000
# 2023-02 23.609000 1927.800000 1439.490000
# 2023-03 20.766000 1840.500000 1488.620000
# 2023-04 24.021000 1983.900000 1487.660000
#
# [184 rows x 22 columns]

# %%
## 경제심리지수, 기계류내수출, 장단기금리차, 외환보유액, 뉴스심리지수, 원달러,G20, 천연가스, 수출입내물가비율--> 정상적이다
df['재고순환지표']+= 24.9
df['재고순환지표']=np.log1p(df['재고순환지표'])
df['거래량']=np.log1p(df['거래량'])
df['코스피']=np.log1p(df['코스피'])

# # df['천연가스']=np.log1p(df['천연가스'])

df['기계류내수출'] -=100
df['수출입물가비율'] -=100

df['은']=df['은'].diff(1)
df['금']=df['금'].diff(1)
df['구리']=df['구리'].diff(1)
df['미장단기']=df['미장단기'].diff(1)
df['유가']=df['유가'].diff(1)
df['원엔']=df['원엔'].diff(1)
df['건설수주액']=df['건설수주액'].diff(1)

df['종가']=df['종가'].pct_change()

df=df.dropna(axis=0)

# %%
df.drop(['유가','은','원위안'],axis=1,inplace=True)

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# 데이터프레임으로부터 독립변수들을 선택하여 X에 저장
X = df[['재고순환지표', '경제심리지수', '기계류내수출', '건설수주액', '수출입물가비율', '장단기',
       '뉴스심리지수', '원달러', '원엔', 'CD', 'G20', '미장단기', '거래량', '구리', '천연가스', '금',
       '종가']]

# statsmodels의 상수항을 추가하기 위해 X에 상수 열 추가
X = sm.add_constant(X)

# VIF 계산
vif = pd.DataFrame()
vif["Feature"] = X.columns
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# VIF 결과 출력
print(vif)
# Out:
#     Feature   VIF Factor
# 0     const 17835.527439
# 1    재고순환지표     2.180553
# 2    경제심리지수     4.769665
# 3    기계류내수출     1.746779
# 4     건설수주액     1.075335
# 5   수출입물가비율     1.604011
# 6       장단기     4.014427
# 7    뉴스심리지수     3.565726
# 8       원달러     2.623262
# 9        원엔     1.658412
# 10       CD     3.367071
# 11      G20     3.873456
# 12     미장단기     1.290682
# 13      거래량     2.203200
# 14       구리     1.670041
# 15     천연가스     2.468461
# 16        금     1.289308
# 17       종가     1.397463

# %%
df.drop(['외환보유액','코스피'],axis=1,inplace=True)

# %%
### H0가 비정상(non-stationary)이다
### 유의수준보다 p-value가 작으면 기각 --> 정상적 데이터다

from statsmodels.tsa.stattools import adfuller
import pandas as pd
pd.options.display.float_format = '{:.6f}'.format

adf_df = pd.DataFrame()  # 빈 데이터프레임 생성

for i in df.columns:
    adf_sample = adfuller(df[i], autolag='AIC')
    
    adf_result = pd.Series(adf_sample[:4], index=['stat', 'p_value', 'lag', 'observ'])
    sig_level = adf_sample[4]['5%']
    adf_result['5%'] = sig_level
    
    adf_df[i] = adf_result  # 결과를 데이터프레임에 열(column)로 추가

adf_df = adf_df.transpose()  # 행(row)과 열(column)을 전환하여 변환
adf_df
# Out:
#               stat  p_value       lag     observ        5%
# 재고순환지표   -4.223353 0.000601  4.000000 178.000000 -2.877918
# 경제심리지수   -3.325043 0.013795 11.000000 171.000000 -2.878595
# 기계류내수출   -3.823751 0.002673 11.000000 171.000000 -2.878595
# 건설수주액    -3.362024 0.012324 12.000000 170.000000 -2.878696
# 수출입물가비율  -3.070182 0.028840 13.000000 169.000000 -2.878799
# 장단기      -3.516219 0.007580 13.000000 169.000000 -2.878799
# 뉴스심리지수   -5.616294 0.000001 12.000000 170.000000 -2.878696
# 원달러      -3.601805 0.005727  0.000000 182.000000 -2.877555
# 원엔       -6.555653 0.000000  4.000000 178.000000 -2.877918
# CD       -2.823217 0.055033  4.000000 178.000000 -2.877918
# G20      -4.038183 0.001223  5.000000 177.000000 -2.878012
# 미장단기    -11.975178 0.000000  0.000000 182.000000 -2.877555
# 거래량      -2.936745 0.041239  2.000000 180.000000 -2.877735
# 구리      -13.367545 0.000000  0.000000 182.000000 -2.877555
# 천연가스     -3.128143 0.024539  9.000000 173.000000 -2.878396
# 금       -16.709642 0.000000  0.000000 182.000000 -2.877555
# 종가       -5.376827 0.000004  3.000000 179.000000 -2.877826

# %%
from statsmodels.tsa.stattools import grangercausalitytests
#워닝 메시지
import warnings
warnings.filterwarnings('ignore')

#df.replace(',', '', regex=True, inplace=True)
df = df.apply(pd.to_numeric, errors='coerce') # numeric 변환
maxlag= 6
test = 'ssr_chi2test'

def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=True):

    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            # if verbose:print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            min_p_value_index = np.argmin(p_values)
            df.loc[r, c] = min_p_value
            print(r,c)
            print(f'Minimum P-value Index: {min_p_value_index} (Lag: {min_p_value_index + 1})')
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df
df_granger=grangers_causation_matrix(df, variables = df.columns)
#df.to_csv('granger검정.csv')
df_granger
# Out:
# 재고순환지표 재고순환지표
# Minimum P-value Index: 0 (Lag: 1)
# 경제심리지수 재고순환지표
# Minimum P-value Index: 0 (Lag: 1)
# 기계류내수출 재고순환지표
# Minimum P-value Index: 0 (Lag: 1)
# 건설수주액 재고순환지표
# Minimum P-value Index: 1 (Lag: 2)
# 수출입물가비율 재고순환지표
# Minimum P-value Index: 0 (Lag: 1)
# 장단기 재고순환지표
# Minimum P-value Index: 4 (Lag: 5)
# 뉴스심리지수 재고순환지표
# Minimum P-value Index: 0 (Lag: 1)
# 원달러 재고순환지표
# Minimum P-value Index: 1 (Lag: 2)
# 원엔 재고순환지표
# Minimum P-value Index: 2 (Lag: 3)
# CD 재고순환지표
# Minimum P-value Index: 0 (Lag: 1)
# G20 재고순환지표
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 재고순환지표
# Minimum P-value Index: 3 (Lag: 4)
# 거래량 재고순환지표
# Minimum P-value Index: 2 (Lag: 3)
# 구리 재고순환지표
# Minimum P-value Index: 0 (Lag: 1)
# 천연가스 재고순환지표
# Minimum P-value Index: 0 (Lag: 1)
# 금 재고순환지표
# Minimum P-value Index: 0 (Lag: 1)
# 종가 재고순환지표
# Minimum P-value Index: 2 (Lag: 3)
# 재고순환지표 경제심리지수
# Minimum P-value Index: 2 (Lag: 3)
# 경제심리지수 경제심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 기계류내수출 경제심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 건설수주액 경제심리지수
# Minimum P-value Index: 3 (Lag: 4)
# 수출입물가비율 경제심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 장단기 경제심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 뉴스심리지수 경제심리지수
# Minimum P-value Index: 2 (Lag: 3)
# 원달러 경제심리지수
# Minimum P-value Index: 2 (Lag: 3)
# 원엔 경제심리지수
# Minimum P-value Index: 1 (Lag: 2)
# CD 경제심리지수
# Minimum P-value Index: 0 (Lag: 1)
# G20 경제심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 경제심리지수
# Minimum P-value Index: 1 (Lag: 2)
# 거래량 경제심리지수
# Minimum P-value Index: 3 (Lag: 4)
# 구리 경제심리지수
# Minimum P-value Index: 1 (Lag: 2)
# 천연가스 경제심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 금 경제심리지수
# Minimum P-value Index: 5 (Lag: 6)
# 종가 경제심리지수
# Minimum P-value Index: 1 (Lag: 2)
# 재고순환지표 기계류내수출
# Minimum P-value Index: 0 (Lag: 1)
# 경제심리지수 기계류내수출
# Minimum P-value Index: 5 (Lag: 6)
# 기계류내수출 기계류내수출
# Minimum P-value Index: 0 (Lag: 1)
# 건설수주액 기계류내수출
# Minimum P-value Index: 2 (Lag: 3)
# 수출입물가비율 기계류내수출
# Minimum P-value Index: 0 (Lag: 1)
# 장단기 기계류내수출
# Minimum P-value Index: 0 (Lag: 1)
# 뉴스심리지수 기계류내수출
# Minimum P-value Index: 5 (Lag: 6)
# 원달러 기계류내수출
# Minimum P-value Index: 3 (Lag: 4)
# 원엔 기계류내수출
# Minimum P-value Index: 3 (Lag: 4)
# CD 기계류내수출
# Minimum P-value Index: 0 (Lag: 1)
# G20 기계류내수출
# Minimum P-value Index: 2 (Lag: 3)
# 미장단기 기계류내수출
# Minimum P-value Index: 1 (Lag: 2)
# 거래량 기계류내수출
# Minimum P-value Index: 0 (Lag: 1)
# 구리 기계류내수출
# Minimum P-value Index: 2 (Lag: 3)
# 천연가스 기계류내수출
# Minimum P-value Index: 5 (Lag: 6)
# 금 기계류내수출
# Minimum P-value Index: 2 (Lag: 3)
# 종가 기계류내수출
# Minimum P-value Index: 1 (Lag: 2)
# 재고순환지표 건설수주액
# Minimum P-value Index: 1 (Lag: 2)
# 경제심리지수 건설수주액
# Minimum P-value Index: 0 (Lag: 1)
# 기계류내수출 건설수주액
# Minimum P-value Index: 3 (Lag: 4)
# 건설수주액 건설수주액
# Minimum P-value Index: 0 (Lag: 1)
# 수출입물가비율 건설수주액
# Minimum P-value Index: 0 (Lag: 1)
# 장단기 건설수주액
# Minimum P-value Index: 1 (Lag: 2)
# 뉴스심리지수 건설수주액
# Minimum P-value Index: 2 (Lag: 3)
# 원달러 건설수주액
# Minimum P-value Index: 1 (Lag: 2)
# 원엔 건설수주액
# Minimum P-value Index: 0 (Lag: 1)
# CD 건설수주액
# Minimum P-value Index: 0 (Lag: 1)
# G20 건설수주액
# Minimum P-value Index: 5 (Lag: 6)
# 미장단기 건설수주액
# Minimum P-value Index: 1 (Lag: 2)
# 거래량 건설수주액
# Minimum P-value Index: 2 (Lag: 3)
# 구리 건설수주액
# Minimum P-value Index: 1 (Lag: 2)
# 천연가스 건설수주액
# Minimum P-value Index: 3 (Lag: 4)
# 금 건설수주액
# Minimum P-value Index: 5 (Lag: 6)
# 종가 건설수주액
# Minimum P-value Index: 0 (Lag: 1)
# 재고순환지표 수출입물가비율
# Minimum P-value Index: 4 (Lag: 5)
# 경제심리지수 수출입물가비율
# Minimum P-value Index: 1 (Lag: 2)
# 기계류내수출 수출입물가비율
# Minimum P-value Index: 4 (Lag: 5)
# 건설수주액 수출입물가비율
# Minimum P-value Index: 1 (Lag: 2)
# 수출입물가비율 수출입물가비율
# Minimum P-value Index: 0 (Lag: 1)
# 장단기 수출입물가비율
# Minimum P-value Index: 0 (Lag: 1)
# 뉴스심리지수 수출입물가비율
# Minimum P-value Index: 5 (Lag: 6)
# 원달러 수출입물가비율
# Minimum P-value Index: 5 (Lag: 6)
# 원엔 수출입물가비율
# Minimum P-value Index: 5 (Lag: 6)
# CD 수출입물가비율
# Minimum P-value Index: 1 (Lag: 2)
# G20 수출입물가비율
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 수출입물가비율
# Minimum P-value Index: 5 (Lag: 6)
# 거래량 수출입물가비율
# Minimum P-value Index: 0 (Lag: 1)
# 구리 수출입물가비율
# Minimum P-value Index: 4 (Lag: 5)
# 천연가스 수출입물가비율
# Minimum P-value Index: 2 (Lag: 3)
# 금 수출입물가비율
# Minimum P-value Index: 2 (Lag: 3)
# 종가 수출입물가비율
# Minimum P-value Index: 4 (Lag: 5)
# 재고순환지표 장단기
# Minimum P-value Index: 4 (Lag: 5)
# 경제심리지수 장단기
# Minimum P-value Index: 0 (Lag: 1)
# 기계류내수출 장단기
# Minimum P-value Index: 0 (Lag: 1)
# 건설수주액 장단기
# Minimum P-value Index: 4 (Lag: 5)
# 수출입물가비율 장단기
# Minimum P-value Index: 3 (Lag: 4)
# 장단기 장단기
# Minimum P-value Index: 0 (Lag: 1)
# 뉴스심리지수 장단기
# Minimum P-value Index: 0 (Lag: 1)
# 원달러 장단기
# Minimum P-value Index: 4 (Lag: 5)
# 원엔 장단기
# Minimum P-value Index: 3 (Lag: 4)
# CD 장단기
# Minimum P-value Index: 0 (Lag: 1)
# G20 장단기
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 장단기
# Minimum P-value Index: 2 (Lag: 3)
# 거래량 장단기
# Minimum P-value Index: 4 (Lag: 5)
# 구리 장단기
# Minimum P-value Index: 3 (Lag: 4)
# 천연가스 장단기
# Minimum P-value Index: 5 (Lag: 6)
# 금 장단기
# Minimum P-value Index: 4 (Lag: 5)
# 종가 장단기
# Minimum P-value Index: 0 (Lag: 1)
# 재고순환지표 뉴스심리지수
# Minimum P-value Index: 1 (Lag: 2)
# 경제심리지수 뉴스심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 기계류내수출 뉴스심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 건설수주액 뉴스심리지수
# Minimum P-value Index: 2 (Lag: 3)
# 수출입물가비율 뉴스심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 장단기 뉴스심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 뉴스심리지수 뉴스심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 원달러 뉴스심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 원엔 뉴스심리지수
# Minimum P-value Index: 1 (Lag: 2)
# CD 뉴스심리지수
# Minimum P-value Index: 5 (Lag: 6)
# G20 뉴스심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 뉴스심리지수
# Minimum P-value Index: 4 (Lag: 5)
# 거래량 뉴스심리지수
# Minimum P-value Index: 5 (Lag: 6)
# 구리 뉴스심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 천연가스 뉴스심리지수
# Minimum P-value Index: 2 (Lag: 3)
# 금 뉴스심리지수
# Minimum P-value Index: 2 (Lag: 3)
# 종가 뉴스심리지수
# Minimum P-value Index: 0 (Lag: 1)
# 재고순환지표 원달러
# Minimum P-value Index: 1 (Lag: 2)
# 경제심리지수 원달러
# Minimum P-value Index: 2 (Lag: 3)
# 기계류내수출 원달러
# Minimum P-value Index: 5 (Lag: 6)
# 건설수주액 원달러
# Minimum P-value Index: 1 (Lag: 2)
# 수출입물가비율 원달러
# Minimum P-value Index: 4 (Lag: 5)
# 장단기 원달러
# Minimum P-value Index: 0 (Lag: 1)
# 뉴스심리지수 원달러
# Minimum P-value Index: 2 (Lag: 3)
# 원달러 원달러
# Minimum P-value Index: 0 (Lag: 1)
# 원엔 원달러
# Minimum P-value Index: 0 (Lag: 1)
# CD 원달러
# Minimum P-value Index: 0 (Lag: 1)
# G20 원달러
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 원달러
# Minimum P-value Index: 1 (Lag: 2)
# 거래량 원달러
# Minimum P-value Index: 3 (Lag: 4)
# 구리 원달러
# Minimum P-value Index: 1 (Lag: 2)
# 천연가스 원달러
# Minimum P-value Index: 1 (Lag: 2)
# 금 원달러
# Minimum P-value Index: 0 (Lag: 1)
# 종가 원달러
# Minimum P-value Index: 3 (Lag: 4)
# 재고순환지표 원엔
# Minimum P-value Index: 0 (Lag: 1)
# 경제심리지수 원엔
# Minimum P-value Index: 0 (Lag: 1)
# 기계류내수출 원엔
# Minimum P-value Index: 4 (Lag: 5)
# 건설수주액 원엔
# Minimum P-value Index: 3 (Lag: 4)
# 수출입물가비율 원엔
# Minimum P-value Index: 3 (Lag: 4)
# 장단기 원엔
# Minimum P-value Index: 4 (Lag: 5)
# 뉴스심리지수 원엔
# Minimum P-value Index: 0 (Lag: 1)
# 원달러 원엔
# Minimum P-value Index: 2 (Lag: 3)
# 원엔 원엔
# Minimum P-value Index: 0 (Lag: 1)
# CD 원엔
# Minimum P-value Index: 1 (Lag: 2)
# G20 원엔
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 원엔
# Minimum P-value Index: 0 (Lag: 1)
# 거래량 원엔
# Minimum P-value Index: 3 (Lag: 4)
# 구리 원엔
# Minimum P-value Index: 5 (Lag: 6)
# 천연가스 원엔
# Minimum P-value Index: 5 (Lag: 6)
# 금 원엔
# Minimum P-value Index: 3 (Lag: 4)
# 종가 원엔
# Minimum P-value Index: 5 (Lag: 6)
# 재고순환지표 CD
# Minimum P-value Index: 0 (Lag: 1)
# 경제심리지수 CD
# Minimum P-value Index: 0 (Lag: 1)
# 기계류내수출 CD
# Minimum P-value Index: 0 (Lag: 1)
# 건설수주액 CD
# Minimum P-value Index: 2 (Lag: 3)
# 수출입물가비율 CD
# Minimum P-value Index: 4 (Lag: 5)
# 장단기 CD
# Minimum P-value Index: 1 (Lag: 2)
# 뉴스심리지수 CD
# Minimum P-value Index: 0 (Lag: 1)
# 원달러 CD
# Minimum P-value Index: 3 (Lag: 4)
# 원엔 CD
# Minimum P-value Index: 3 (Lag: 4)
# CD CD
# Minimum P-value Index: 0 (Lag: 1)
# G20 CD
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 CD
# Minimum P-value Index: 4 (Lag: 5)
# 거래량 CD
# Minimum P-value Index: 4 (Lag: 5)
# 구리 CD
# Minimum P-value Index: 1 (Lag: 2)
# 천연가스 CD
# Minimum P-value Index: 5 (Lag: 6)
# 금 CD
# Minimum P-value Index: 2 (Lag: 3)
# 종가 CD
# Minimum P-value Index: 3 (Lag: 4)
# 재고순환지표 G20
# Minimum P-value Index: 5 (Lag: 6)
# 경제심리지수 G20
# Minimum P-value Index: 0 (Lag: 1)
# 기계류내수출 G20
# Minimum P-value Index: 0 (Lag: 1)
# 건설수주액 G20
# Minimum P-value Index: 1 (Lag: 2)
# 수출입물가비율 G20
# Minimum P-value Index: 0 (Lag: 1)
# 장단기 G20
# Minimum P-value Index: 0 (Lag: 1)
# 뉴스심리지수 G20
# Minimum P-value Index: 5 (Lag: 6)
# 원달러 G20
# Minimum P-value Index: 0 (Lag: 1)
# 원엔 G20
# Minimum P-value Index: 1 (Lag: 2)
# CD G20
# Minimum P-value Index: 0 (Lag: 1)
# G20 G20
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 G20
# Minimum P-value Index: 1 (Lag: 2)
# 거래량 G20
# Minimum P-value Index: 5 (Lag: 6)
# 구리 G20
# Minimum P-value Index: 2 (Lag: 3)
# 천연가스 G20
# Minimum P-value Index: 0 (Lag: 1)
# 금 G20
# Minimum P-value Index: 4 (Lag: 5)
# 종가 G20
# Minimum P-value Index: 3 (Lag: 4)
# 재고순환지표 미장단기
# Minimum P-value Index: 2 (Lag: 3)
# 경제심리지수 미장단기
# Minimum P-value Index: 1 (Lag: 2)
# 기계류내수출 미장단기
# Minimum P-value Index: 0 (Lag: 1)
# 건설수주액 미장단기
# Minimum P-value Index: 1 (Lag: 2)
# 수출입물가비율 미장단기
# Minimum P-value Index: 5 (Lag: 6)
# 장단기 미장단기
# Minimum P-value Index: 5 (Lag: 6)
# 뉴스심리지수 미장단기
# Minimum P-value Index: 1 (Lag: 2)
# 원달러 미장단기
# Minimum P-value Index: 3 (Lag: 4)
# 원엔 미장단기
# Minimum P-value Index: 0 (Lag: 1)
# CD 미장단기
# Minimum P-value Index: 4 (Lag: 5)
# G20 미장단기
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 미장단기
# Minimum P-value Index: 0 (Lag: 1)
# 거래량 미장단기
# Minimum P-value Index: 4 (Lag: 5)
# 구리 미장단기
# Minimum P-value Index: 0 (Lag: 1)
# 천연가스 미장단기
# Minimum P-value Index: 3 (Lag: 4)
# 금 미장단기
# Minimum P-value Index: 0 (Lag: 1)
# 종가 미장단기
# Minimum P-value Index: 2 (Lag: 3)
# 재고순환지표 거래량
# Minimum P-value Index: 2 (Lag: 3)
# 경제심리지수 거래량
# Minimum P-value Index: 3 (Lag: 4)
# 기계류내수출 거래량
# Minimum P-value Index: 3 (Lag: 4)
# 건설수주액 거래량
# Minimum P-value Index: 2 (Lag: 3)
# 수출입물가비율 거래량
# Minimum P-value Index: 0 (Lag: 1)
# 장단기 거래량
# Minimum P-value Index: 1 (Lag: 2)
# 뉴스심리지수 거래량
# Minimum P-value Index: 0 (Lag: 1)
# 원달러 거래량
# Minimum P-value Index: 1 (Lag: 2)
# 원엔 거래량
# Minimum P-value Index: 0 (Lag: 1)
# CD 거래량
# Minimum P-value Index: 4 (Lag: 5)
# G20 거래량
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 거래량
# Minimum P-value Index: 1 (Lag: 2)
# 거래량 거래량
# Minimum P-value Index: 0 (Lag: 1)
# 구리 거래량
# Minimum P-value Index: 1 (Lag: 2)
# 천연가스 거래량
# Minimum P-value Index: 5 (Lag: 6)
# 금 거래량
# Minimum P-value Index: 2 (Lag: 3)
# 종가 거래량
# Minimum P-value Index: 1 (Lag: 2)
# 재고순환지표 구리
# Minimum P-value Index: 1 (Lag: 2)
# 경제심리지수 구리
# Minimum P-value Index: 0 (Lag: 1)
# 기계류내수출 구리
# Minimum P-value Index: 5 (Lag: 6)
# 건설수주액 구리
# Minimum P-value Index: 5 (Lag: 6)
# 수출입물가비율 구리
# Minimum P-value Index: 0 (Lag: 1)
# 장단기 구리
# Minimum P-value Index: 2 (Lag: 3)
# 뉴스심리지수 구리
# Minimum P-value Index: 0 (Lag: 1)
# 원달러 구리
# Minimum P-value Index: 4 (Lag: 5)
# 원엔 구리
# Minimum P-value Index: 0 (Lag: 1)
# CD 구리
# Minimum P-value Index: 1 (Lag: 2)
# G20 구리
# Minimum P-value Index: 1 (Lag: 2)
# 미장단기 구리
# Minimum P-value Index: 0 (Lag: 1)
# 거래량 구리
# Minimum P-value Index: 4 (Lag: 5)
# 구리 구리
# Minimum P-value Index: 0 (Lag: 1)
# 천연가스 구리
# Minimum P-value Index: 2 (Lag: 3)
# 금 구리
# Minimum P-value Index: 4 (Lag: 5)
# 종가 구리
# Minimum P-value Index: 1 (Lag: 2)
# 재고순환지표 천연가스
# Minimum P-value Index: 4 (Lag: 5)
# 경제심리지수 천연가스
# Minimum P-value Index: 0 (Lag: 1)
# 기계류내수출 천연가스
# Minimum P-value Index: 4 (Lag: 5)
# 건설수주액 천연가스
# Minimum P-value Index: 5 (Lag: 6)
# 수출입물가비율 천연가스
# Minimum P-value Index: 4 (Lag: 5)
# 장단기 천연가스
# Minimum P-value Index: 3 (Lag: 4)
# 뉴스심리지수 천연가스
# Minimum P-value Index: 2 (Lag: 3)
# 원달러 천연가스
# Minimum P-value Index: 4 (Lag: 5)
# 원엔 천연가스
# Minimum P-value Index: 5 (Lag: 6)
# CD 천연가스
# Minimum P-value Index: 0 (Lag: 1)
# G20 천연가스
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 천연가스
# Minimum P-value Index: 2 (Lag: 3)
# 거래량 천연가스
# Minimum P-value Index: 3 (Lag: 4)
# 구리 천연가스
# Minimum P-value Index: 5 (Lag: 6)
# 천연가스 천연가스
# Minimum P-value Index: 0 (Lag: 1)
# 금 천연가스
# Minimum P-value Index: 0 (Lag: 1)
# 종가 천연가스
# Minimum P-value Index: 3 (Lag: 4)
# 재고순환지표 금
# Minimum P-value Index: 3 (Lag: 4)
# 경제심리지수 금
# Minimum P-value Index: 1 (Lag: 2)
# 기계류내수출 금
# Minimum P-value Index: 4 (Lag: 5)
# 건설수주액 금
# Minimum P-value Index: 0 (Lag: 1)
# 수출입물가비율 금
# Minimum P-value Index: 0 (Lag: 1)
# 장단기 금
# Minimum P-value Index: 4 (Lag: 5)
# 뉴스심리지수 금
# Minimum P-value Index: 0 (Lag: 1)
# 원달러 금
# Minimum P-value Index: 0 (Lag: 1)
# 원엔 금
# Minimum P-value Index: 2 (Lag: 3)
# CD 금
# Minimum P-value Index: 0 (Lag: 1)
# G20 금
# Minimum P-value Index: 3 (Lag: 4)
# 미장단기 금
# Minimum P-value Index: 5 (Lag: 6)
# 거래량 금
# Minimum P-value Index: 0 (Lag: 1)
# 구리 금
# Minimum P-value Index: 0 (Lag: 1)
# 천연가스 금
# Minimum P-value Index: 0 (Lag: 1)
# 금 금
# Minimum P-value Index: 0 (Lag: 1)
# 종가 금
# Minimum P-value Index: 3 (Lag: 4)
# 재고순환지표 종가
# Minimum P-value Index: 0 (Lag: 1)
# 경제심리지수 종가
# Minimum P-value Index: 0 (Lag: 1)
# 기계류내수출 종가
# Minimum P-value Index: 3 (Lag: 4)
# 건설수주액 종가
# Minimum P-value Index: 3 (Lag: 4)
# 수출입물가비율 종가
# Minimum P-value Index: 0 (Lag: 1)
# 장단기 종가
# Minimum P-value Index: 5 (Lag: 6)
# 뉴스심리지수 종가
# Minimum P-value Index: 4 (Lag: 5)
# 원달러 종가
# Minimum P-value Index: 2 (Lag: 3)
# 원엔 종가
# Minimum P-value Index: 2 (Lag: 3)
# CD 종가
# Minimum P-value Index: 2 (Lag: 3)
# G20 종가
# Minimum P-value Index: 0 (Lag: 1)
# 미장단기 종가
# Minimum P-value Index: 0 (Lag: 1)
# 거래량 종가
# Minimum P-value Index: 0 (Lag: 1)
# 구리 종가
# Minimum P-value Index: 4 (Lag: 5)
# 천연가스 종가
# Minimum P-value Index: 3 (Lag: 4)
# 금 종가
# Minimum P-value Index: 3 (Lag: 4)
# 종가 종가
# Minimum P-value Index: 0 (Lag: 1)
#            재고순환지표_x  경제심리지수_x  기계류내수출_x  건설수주액_x  수출입물가비율_x    장단기_x
# 재고순환지표_y   1.000000  0.000000  0.039700 0.128200   0.000200 0.000000  \
# 경제심리지수_y   0.000000  1.000000  0.186400 0.065400   0.000300 0.000000
# 기계류내수출_y   0.000000  0.001000  1.000000 0.323400   0.016300 0.001300
# 건설수주액_y    0.227000  0.121400  0.033900 1.000000   0.246800 0.007200
# 수출입물가비율_y  0.008900  0.000000  0.015100 0.105000   1.000000 0.000000
# 장단기_y      0.000000  0.000000  0.000000 0.000700   0.000000 1.000000
# 뉴스심리지수_y   0.076800  0.029500  0.450700 0.278200   0.000400 0.072000
# 원달러_y      0.000000  0.007200  0.191400 0.251300   0.095100 0.000000
# 원엔_y       0.000000  0.000900  0.157900 0.075300   0.009400 0.027100
# CD_y       0.000000  0.000000  0.000100 0.129600   0.000000 0.022600
# G20_y      0.023500  0.009500  0.002000 0.011600   0.162000 0.056200
# 미장단기_y     0.063500  0.002900  0.004000 0.219400   0.199800 0.075000
# 거래량_y      0.094900  0.104600  0.140000 0.128100   0.029500 0.007100
# 구리_y       0.036400  0.031500  0.417900 0.463400   0.000000 0.051500
# 천연가스_y     0.012500  0.004700  0.749700 0.139000   0.048100 0.000200
# 금_y        0.362300  0.196100  0.737500 0.002400   0.173000 0.012700
# 종가_y       0.006500  0.000000  0.170400 0.119400   0.000200 0.002300
#
#            뉴스심리지수_x    원달러_x     원엔_x     CD_x    G20_x   미장단기_x    거래량_x
# 재고순환지표_y   0.000100 0.000000 0.000000 0.000000 0.014200 0.000000 0.000500  \
# 경제심리지수_y   0.000000 0.070000 0.000000 0.000000 0.000000 0.125400 0.000100
# 기계류내수출_y   0.000000 0.097500 0.004900 0.011300 0.007900 0.046600 0.456700
# 건설수주액_y    0.333500 0.195600 0.413200 0.144800 0.065400 0.239200 0.584000
# 수출입물가비율_y  0.000000 0.008900 0.002600 0.068200 0.000000 0.163100 0.371600
# 장단기_y      0.088900 0.002200 0.001100 0.000000 0.000000 0.000000 0.000200
# 뉴스심리지수_y   1.000000 0.024700 0.794400 0.000400 0.001100 0.255900 0.015400
# 원달러_y      0.000000 1.000000 0.014900 0.000000 0.003200 0.024000 0.162300
# 원엔_y       0.000000 0.026600 1.000000 0.000000 0.119200 0.008400 0.118900
# CD_y       0.004300 0.063600 0.000200 1.000000 0.000000 0.008000 0.004400
# G20_y      0.000000 0.382600 0.248300 0.002300 1.000000 0.648400 0.051300
# 미장단기_y     0.083400 0.443900 0.027400 0.025900 0.151700 1.000000 0.295900
# 거래량_y      0.028800 0.069100 0.040700 0.010600 0.009400 0.006500 1.000000
# 구리_y       0.000000 0.011100 0.546900 0.019200 0.010600 0.268400 0.006000
# 천연가스_y     0.005300 0.026200 0.302400 0.029400 0.030800 0.217100 0.006700
# 금_y        0.456300 0.012800 0.043100 0.687500 0.026600 0.103700 0.190400
# 종가_y       0.000000 0.000200 0.138400 0.000900 0.000200 0.008500 0.006700
#
#               구리_x   천연가스_x      금_x     종가_x
# 재고순환지표_y  0.000000 0.000000 0.142300 0.000100
# 경제심리지수_y  0.000000 0.002500 0.062300 0.000000
# 기계류내수출_y  0.033800 0.088700 0.143500 0.000300
# 건설수주액_y   0.578000 0.013600 0.046800 0.341900
# 수출입물가비율_y 0.000000 0.069000 0.096100 0.000000
# 장단기_y     0.293700 0.005500 0.126400 0.008900
# 뉴스심리지수_y  0.033500 0.002300 0.015300 0.793300
# 원달러_y     0.000700 0.000000 0.672100 0.004700
# 원엔_y      0.001200 0.000100 0.195100 0.421300
# CD_y      0.001100 0.000000 0.370500 0.005900
# G20_y     0.114900 0.008800 0.511200 0.025100
# 미장단기_y    0.518300 0.008000 0.109300 0.001500
# 거래량_y     0.000900 0.000400 0.142700 0.003200
# 구리_y      1.000000 0.009200 0.035300 0.006800
# 천연가스_y    0.000000 1.000000 0.447500 0.153000
# 금_y       0.228800 0.222600 1.000000 0.211000
# 종가_y      0.006300 0.009400 0.227900 1.000000

# %%
df.columns
# Out:
# Index(['재고순환지표', '경제심리지수', '기계류내수출', '건설수주액', '수출입물가비율', '장단기', '뉴스심리지수',
#        '원달러', '원엔', 'CD', 'G20', '미장단기', '거래량', '구리', '천연가스', '금', '종가'],
#       dtype='object')

# %%
import statsmodels.api as sm
from statsmodels.tsa.api import VAR

# train 데이터 프레임 정의
train_data = df.iloc[:165][['재고순환지표','경제심리지수','기계류내수출','수출입물가비율','CD','장단기','거래량','구리','종가']]
train = pd.DataFrame(train_data)

# test 데이터 프레임 정의
test_data = df.iloc[165:][['재고순환지표','경제심리지수','기계류내수출','수출입물가비율','CD','장단기','거래량','구리','종가']]
test = pd.DataFrame(test_data)

# Initialize empty DataFrame to store predictions
pred = pd.DataFrame(columns=train.columns)

for t in range(len(test)):
    # Fit VAR model
    model_var = VAR(endog=train)
    model_fit = model_var.fit(maxlags=6, ic='aic')

    # One step forecast
    forecast = model_fit.forecast(train.values[-6:], steps=1)

    # Append the prediction to pred DataFrame
    pred = pd.concat([pred, pd.DataFrame(forecast, columns=pred.columns)], ignore_index=True)

    # Append the current test observation to train DataFrame for the next training
    train = pd.concat([train, test.iloc[[t]]], ignore_index=True)

pred.reset_index(drop=True, inplace=True)

# %%
pred['date']= test.index
pred=pred.set_index('date')

# %%
pred
# Out:
#           재고순환지표     경제심리지수    기계류내수출    수출입물가비율       CD      장단기      거래량
# date
# 2021-11 2.818977 105.139305  1.613947 -10.528605 1.187087 1.115198 8.944052  \
# 2021-12 2.820756 106.143079 -0.280566 -11.297297 1.313053 1.423238 9.034605
# 2022-01 2.755101 104.011748  8.500919 -10.748212 1.367643 1.113168 9.043357
# 2022-02 3.102490 104.909741 10.396778 -11.310973 1.348182 0.996285 9.076886
# 2022-03 2.812761 104.662733  4.990814 -13.981368 1.525665 1.046340 8.779962
# 2022-04 2.770432 104.298583  2.406271 -15.663555 1.485422 1.357823 8.987673
# 2022-05 3.049918 105.358505  2.106991 -15.060919 1.504950 1.678492 8.953597
# 2022-06 2.782904 106.664984  8.564740 -14.918531 1.808118 1.611874 8.756746
# 2022-07 2.422452 103.175365 11.166658 -14.122556 2.058824 1.873115 9.346495
# 2022-08 2.242817  99.092446  6.693217 -15.607344 1.969367 1.500783 9.107107
# 2022-09 2.040490  97.159675  9.876439 -13.966021 2.923604 1.055565 9.423662
# 2022-10 2.615523  98.086216  8.786347 -15.330411 3.200129 1.202821 9.064914
# 2022-11 2.984653  97.265696 13.661199 -14.290851 3.638924 1.245896 9.050939
# 2022-12 2.592067  94.284048 13.276152 -14.947391 4.073086 0.995047 8.969210
# 2023-01 2.909410  91.851658 14.955166 -14.639457 4.068636 0.423882 9.308946
# 2023-02 2.530244  88.013311  8.475843 -14.212772 3.790043 0.168308 9.152615
# 2023-03 2.239060  92.824298  0.636238 -15.727509 2.964865 0.209455 9.199543
# 2023-04 2.246715  93.389227  0.090312 -15.938904 3.355578 0.129747 9.324434
#
#                구리        종가
# date
# 2021-11  0.046416  0.041310
# 2021-12  0.044702 -0.068920
# 2022-01 -0.100839  0.022919
# 2022-02 -0.040474  0.039355
# 2022-03 -0.017722 -0.027941
# 2022-04 -0.098783  0.027054
# 2022-05  0.094128 -0.054562
# 2022-06  0.181859  0.022357
# 2022-07 -0.119569 -0.086863
# 2022-08  0.470211  0.060543
# 2022-09 -0.264624  0.011587
# 2022-10  0.087717  0.035366
# 2022-11  0.053256  0.001285
# 2022-12  0.041378  0.052150
# 2023-01 -0.277569  0.131395
# 2023-02 -0.426288 -0.019317
# 2023-03  0.039026  0.082200
# 2023-04  0.027331  0.014772

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))

plt.plot(pred.index, pred['종가'],label='예측값')
plt.plot(test.index, test['종가'],label='실제값')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
pred['종가']
# Out:
# date
# 2021-11    0.041310
# 2021-12   -0.068920
# 2022-01    0.022919
# 2022-02    0.039355
# 2022-03   -0.027941
# 2022-04    0.027054
# 2022-05   -0.054562
# 2022-06    0.022357
# 2022-07   -0.086863
# 2022-08    0.060543
# 2022-09    0.011587
# 2022-10    0.035366
# 2022-11    0.001285
# 2022-12    0.052150
# 2023-01    0.131395
# 2023-02   -0.019317
# 2023-03    0.082200
# 2023-04    0.014772
# Name: 종가, dtype: float64

# %%
test['종가']
# Out:
# Date
# 2021-11    0.033961
# 2021-12   -0.078344
# 2022-01    0.060199
# 2022-02   -0.079602
# 2022-03   -0.040206
# 2022-04    0.015971
# 2022-05    0.030698
# 2022-06    0.006262
# 2022-07   -0.086436
# 2022-08    0.065730
# 2022-09   -0.015726
# 2022-10   -0.076629
# 2022-11   -0.028279
# 2022-12    0.030911
# 2023-01   -0.063960
# 2023-02    0.071121
# 2023-03    0.034130
# 2023-04   -0.000645
# Name: 종가, dtype: float64
