# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = '{:.6f}'.format  

# 그래프에서 한글 깨짐 방지
import platform
if platform.system() == "Darwin":          # MAC인 경우
    plt.rc('font', family ="AppleGothic")
else:
    plt.rc('font',family='Malgun Gothic')

#멧플로립에서 음수를 표시
plt.rc('axes',unicode_minus=False)

#워닝 메시지
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import tensorflow as tf
from keras.models import Sequential
from keras.layers import LSTM, Dense

# %%
df=pd.read_csv('./datasets/원본data.csv',index_col=0)

# %%
df.shape
# Out:
# (184, 22)

# %%
dataset=df.values
scaler=StandardScaler()
dataset= scaler.fit_transform(dataset)
print(dataset)
# Out:
# [[ 0.93589755  1.43327182 -0.74157178 ... -0.82491373 -1.74913464
#   -1.49457805]
#  [ 0.80523213  1.42294476 -0.75485022 ... -0.57680883 -1.57284691
#   -1.75012721]
#  [ 0.7220814   1.26803893 -0.75485022 ... -0.07876798 -1.33988349
#   -1.81061445]
#  ...
#  [-1.58238152 -0.73540982  0.37381684 ...  0.44444956  1.76937084
#   -0.3938106 ]
#  [-1.61801754 -0.73540982 -0.40961088 ...  0.01064744  1.4817088
#   -0.27075728]
#  [-1.66553224 -0.61148516 -0.3432187  ...  0.50731501  1.95422583
#   -0.27316174]]

# %%
# dataset =df.values
# data_mean = dataset[:148].mean(axis=0)
# data_std = dataset[:148].std(axis=0)
# dataset = (dataset-data_mean)/data_std
# print(dataset)

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size, target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i - history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i + target_size])
        else:
            labels.append(target[i:i + target_size])
    return np.array(data), np.array(labels)

# %% [markdown]
# - dataset: 입력으로 사용될 다변량 시계열 데이터. 이는 2D 배열 또는 리스트로 표현됩니다.
# - target: 예측하고자 하는 값 또는 시계열 데이터의 특정 특징(feature). 이는 1D 배열 또는 리스트로 표현됩니다.
# - start_index: 데이터에서 입력 시퀀스의 시작 인덱스입니다.
# - end_index: 데이터에서 입력 시퀀스의 종료 인덱스입니다. 만약 None으로 설정되면, 데이터의 끝에서 target_size를 뺀 값으로 설정됩니다.
# - history_size: 입력으로 사용할 이전 시점들의 크기입니다. 이 값은 현재 시점을 포함하지 않습니다.
# - target_size: 예측하고자 하는 미래 시점들의 크기입니다.
# - step: 입력 시퀀스를 만들기 위해 사용할 간격(step)입니다.
# - single_step: 예측할 시계열 데이터가 단일 시점인지 여부를 나타냅니다. 기본값은 False이며, 다변량 시계열을 예측하는 경우 False로 설정되어야 합니다.

# %%
past_history = 2
future_target = 1
STEP = 1

X_train, y_train = multivariate_data(dataset, dataset[:, -1], 0, 148, past_history,
                                                   future_target, STEP, single_step=False)
X_test, y_test = multivariate_data(dataset, dataset[:, -1], 148, None, past_history,
                                               future_target, STEP, single_step=False)

print('Single window of past history : {}'.format(X_train[0].shape))
# Out:
# Single window of past history : (2, 22)

# %%
X_train.shape
# Out:
# (146, 2, 22)

# %%
X_test.shape
# Out:
# (33, 2, 22)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# LSTM 모델 생성
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]), dropout=0.3))
model.add(LSTM(50,dropout=0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# 모델 학습
model.fit(X_train, y_train, epochs=200, batch_size=64, verbose=1)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 4s 10ms/step - loss: 1.1027
# Epoch 2/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0270
# Epoch 3/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9523
# Epoch 4/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8894
# Epoch 5/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7885
# Epoch 6/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.
200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0521
# Epoch 133/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0565
# Epoch 134/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0593
# Epoch 135/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0470
# Epoch 136/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0493
# Epoch 137/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0721
# Epoch 138/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0534
# Epoch 139/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0557
# Epoch 140/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0555
# Epoch 141/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0459
# Epoch 142/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0631
# Epoch 143/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0721
# Epoch 144/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0607
# Epoch 145/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0504
# Epoch 146/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0509
# Epoch 147/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0617
# Epoch 148/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0540
# Epoch 149/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0602
# Epoch 150/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0473
# Epoch 151/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0510
# Epoch 152/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0582
# Epoch 153/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0585
# Epoch 154/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0600
# Epoch 155/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0569
# Epoch 156/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0586
# Epoch 157/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0591
# Epoch 158/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0533
# Epoch 159/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0472
# Epoch 160/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0621
# Epoch 161/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0568
# Epoch 162/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0477
# Epoch 163/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0523
# Epoch 164/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0558
# Epoch 165/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0536
# Epoch 166/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0554
# Epoch 167/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0428
# Epoch 168/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0401
# Epoch 169/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0508
# Epoch 170/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0613
# Epoch 171/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0480
# Epoch 172/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0473
# Epoch 173/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0590
# Epoch 174/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0501
# Epoch 175/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0518
# Epoch 176/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0647
# Epoch 177/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0447
# Epoch 178/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0510
# Epoch 179/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0458
# Epoch 180/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0510
# Epoch 181/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0462
# Epoch 182/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0613
# Epoch 183/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0569
# Epoch 184/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0465
# Epoch 185/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0432
# Epoch 186/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0595
# Epoch 187/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0550
# Epoch 188/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0457
# Epoch 189/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0574
# Epoch 190/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0521
# Epoch 191/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0480
# Epoch 192/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0411
# Epoch 193/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0437
# Epoch 194/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0505
# Epoch 195/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0503
# Epoch 196/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0430
# Epoch 197/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0487
# Epoch 198/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0547
# Epoch 199/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0539
# Epoch 200/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0383

# %%
# 예측
train_predict = model.predict(X_train)
val_predict = model.predict(X_test)

scaler_y = StandardScaler()
scaled_data_y = scaler_y.fit_transform(df.iloc[:, -1].values.reshape(-1,1))
# 예측 값 스케일 역변환
train_predict = scaler_y.inverse_transform(train_predict)
val_predict = scaler_y.inverse_transform(val_predict)

# 실제 값 스케일 역변환
y_train = scaler_y.inverse_transform(y_train.reshape(-1,1))
y_test = scaler_y.inverse_transform(y_test.reshape(-1,1))
# Out:
# 5/5 [==============================] - 1s 4ms/step
# 2/2 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
# Add the training set to the plot:
plt.plot(y_train, color='green', label='Train')
# Plot the test and prediction data:
plt.plot(range(len(y_train), len(y_train)+len(y_test)), y_test, color='blue', label='Real')
plt.plot(range(len(y_train), len(y_train)+len(y_test)), val_predict, color='red', label='Prediction')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
df=pd.read_csv('./datasets/원본data.csv',index_col=0)
dataset=df.values
scaler=StandardScaler()
dataset= scaler.fit_transform(dataset)
print(dataset)
# Out:
# [[ 0.93589755  1.43327182 -0.74157178 ... -0.82491373 -1.74913464
#   -1.49457805]
#  [ 0.80523213  1.42294476 -0.75485022 ... -0.57680883 -1.57284691
#   -1.75012721]
#  [ 0.7220814   1.26803893 -0.75485022 ... -0.07876798 -1.33988349
#   -1.81061445]
#  ...
#  [-1.58238152 -0.73540982  0.37381684 ...  0.44444956  1.76937084
#   -0.3938106 ]
#  [-1.61801754 -0.73540982 -0.40961088 ...  0.01064744  1.4817088
#   -0.27075728]
#  [-1.66553224 -0.61148516 -0.3432187  ...  0.50731501  1.95422583
#   -0.27316174]]

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size, target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i - history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i + target_size])
        else:
            labels.append(target[i:i + target_size])
    return np.array(data), np.array(labels)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# LSTM 모델 생성
model = Sequential()
model.add(LSTM(256, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]), dropout=0.5))
model.add(LSTM(64, return_sequences=True, dropout=0.5))
model.add(LSTM(64, dropout=0.5))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# 모델 학습
model.fit(X_train, y_train, epochs=200, batch_size=64, verbose=1)

# 예측
train_predict = model.predict(X_train)
val_predict = model.predict(X_test)

scaler_y = StandardScaler()
scaled_data_y = scaler_y.fit_transform(df.iloc[:, -1].values.reshape(-1,1))
# 예측 값 스케일 역변환
train_predict = scaler_y.inverse_transform(train_predict)
val_predict = scaler_y.inverse_transform(val_predict)

# 실제 값 스케일 역변환
y_train = scaler_y.inverse_transform(y_train.reshape(-1,1))
y_test = scaler_y.inverse_transform(y_test.reshape(-1,1))


import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
# Add the training set to the plot:
plt.plot(y_train, color='green', label='Train')
# Plot the test and prediction data:
plt.plot(range(len(y_train), len(y_train)+len(y_test)), y_test, color='blue', label='Real')
plt.plot(range(len(y_train), len(y_train)+len(y_test)), val_predict, color='red', label='Prediction')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 3/3 [==============================] - 5s 17ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 2/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 3/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 4/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 5/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 6/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 7/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 8/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 9/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 10/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 11/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 12/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 13/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 14/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 15/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 16/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 17/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 18/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 19/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 20/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 21/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 22/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 23/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 24/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 25/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 26/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 27/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 28/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 29/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 30/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 31/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 32/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 33/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 34/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 35/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 36/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 37/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 38/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 39/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 40/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 41/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 42/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 43/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 44/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 45/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 46/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 47/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 48/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 49/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 50/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 51/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 52/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 53/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 54/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 55/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 56/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 57/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 58/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 59/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 60/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 61/200
# 3/3 [==============================] - 0s 32ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 62/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 63/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 64/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 65/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 66/200
# 3/3 [==============================] - 0s 18ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 67/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 68/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 69/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 70/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 71/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 72/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 73/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 74/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 75/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 76/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 77/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 78/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 79/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 80/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 81/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 82/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 83/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 84/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 85/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 86/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 87/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 88/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 89/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 90/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 91/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 92/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 93/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 94/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 95/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 96/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 97/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 98/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 99/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 100/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 101/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 102/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 103/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 104/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 105/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 106/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 107/200
# 3/3 [==============================] - 0s 18ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 108/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 109/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 110/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 111/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 112/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 113/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 114/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 115/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 116/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 117/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 118/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 119/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 120/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 121/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 122/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 123/200
# 3/3 [==============================] - 0s 17ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 124/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 125/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 126/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 127/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 128/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 129/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 130/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 131/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 132/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 133/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 134/200
# 3/3 [==============================] - 0s 20ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 135/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 136/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 137/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 138/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 139/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 140/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 141/200
# 3/3 [==============================] - 0s 29ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 142/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 143/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 144/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 145/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 146/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 147/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 148/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 149/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 150/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 151/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 152/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 153/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 154/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 155/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 156/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 157/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 158/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 159/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 160/200
# 3/3 [==============================] - 0s 29ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 161/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 162/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 163/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 164/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 165/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 166/200
# 3/3 [==============================] - 0s 18ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 167/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 168/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 169/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 170/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 171/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 172/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 173/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 174/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 175/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 176/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 177/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 178/200
# 3/3 [==============================] - 0s 30ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 179/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 180/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 181/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 182/200
# 3/3 [==============================] - 0s 16ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 183/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 184/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 185/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 186/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 187/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 188/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 189/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 190/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 191/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 192/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 193/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 194/200
# 3/3 [==============================] - 0s 31ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 195/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 196/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 197/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 198/200
# 3/3 [==============================] - 0s 14ms/step - loss: 286457700294335433550046540333056.0000
# Epoch 199/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457661608709205881912949735424.0000
# Epoch 200/200
# 3/3 [==============================] - 0s 15ms/step - loss: 286457700294335433550046540333056.0000
# 5/5 [==============================] - 1s 5ms/step
# 2/2 [==============================] - 0s 3ms/step
